# %%
import numpy as np

# %%
import sys, glob

# %%
import matplotlib.pyplot as plt

# %%
from pycurrents.adcp.rdiraw import Multiread

# %%
# %matplotlib inline

# %%
pname = '/Volumes/wjlee_apl_2/2017_cruises/ADCP_RR1713/raw/os150/'
fname = glob.glob(pname+'rr2017_207_*.raw')
fname
# Out:
# ['/Volumes/wjlee_apl_2/2017_cruises/ADCP_RR1713/raw/os150/rr2017_207_65746.raw',
#  '/Volumes/wjlee_apl_2/2017_cruises/ADCP_RR1713/raw/os150/rr2017_207_72000.raw']

# %%
m=Multiread(fname,'os')

# %%
data=m.read()

# %%
data.pingtype
# Out:
# 'bb'

# %%
m.list_configs()
# Out:
# # index (ping, NCells, CellSize, Blank, Pulse) nfiles
# 0    (bb, 80, 4.0, 4.0, 4.0)     2
# 1    (nb, 60, 8.0, 4.0, 8.0)     2

# %%
data
# Out:
# {'Bin1Dist': 8.22,
#  'Blank': 4.0,
#  'CellSize': 4.0,
#  'FL': {'Bin1Dist': 822,
#   'Blank': 400,
#   'CellSize': 400,
#   'EA': -400,
#   'EV': 0,
#   'EVMax': 1000,
#   'EX': 0,
#   'EZ': 93,
#   'FWR': 19,
#   'FWV': 23,
#   'LowCorrThresh': 120,
#   'NBeams': 4,
#   'NCells': 80,
#   'NCodeReps': 10,
#   'NPings': 1,
#   'PGMin': 0,
#   'Pulse': 407,
#   'RL0': 1,
#   'RL1': 1,
#   'SA': 29,
#   'SPM': 1,
#   'SysCfg': 585,
#   'TPP_hun': 10,
#   'TPP_min': 0,
#   'TPP_sec': 1,
#   'TransLag': 40,
#   'WA': 255,
#   'spare1': 0,
#   'spare2': 6,
#   'spare3': 0},
#  'NBeams': 4,
#  'NCells': 80,
#  'NPings': 1,
#  'Pulse': 4.07,
#  'VL': array([ (1, 17, 7, 27, 18, 15, 45, 11, 0, 0, 1491, 0, 0, 0, 0, 35, 1044, 0, 0, 52, 0, 0, 0, '', 0, 0, 0, 0),
#         (2, 17, 7, 27, 18, 15, 47, 43, 0, 0, 1491, 0, 0, 0, 0, 35, 1029, 0, 0, 52, 0, 0, 0, '', 0, 0, 0, 0),
#         (3, 17, 7, 27, 18, 15, 49, 75, 0, 0, 1491, 0, 0, 0, 0, 35, 1051, 0, 0, 52, 0, 0, 0, '', 0, 0, 0, 0),
#         ...,
#         (4345, 17, 7, 27, 21, 5, 33, 63, 0, 0, 1496, 0, 0, 0, 0, 35, 1173, 0, 0, 53, 0, 0, 0, '', 3, 0, 0, 0),
#         (4346, 17, 7, 27, 21, 5, 35, 98, 0, 0, 1496, 0, 0, 0, 0, 35, 1188, 0, 0, 53, 0, 0, 0, '', 0, 0, 0, 0),
#         (4347, 17, 7, 27, 21, 5, 38, 33, 0, 0, 1496, 0, 0, 0, 0, 35, 1197, 0, 0, 53, 0, 0, 0, '', 3, 0, 0, 0)],
#        dtype=[('EnsNum', '<u2'), ('Year', 'u1'), ('Month', 'u1'), ('Day', 'u1'), ('Hour', 'u1'), ('Minute', 'u1'), ('Second', 'u1'), ('Hundredths', 'u1'), ('EnsNumMSB', 'u1'), ('BIT', '<u2'), ('SoundSpeed', '<u2'), ('XducerDepth', '<u2'), ('Heading', '<u2'), ('Pitch', '<i2'), ('Roll', '<i2'), ('Salinity', '<u2'), ('Temperature', '<i2'), ('MPT_minutes', 'u1'), ('MPT_seconds', 'u1'), ('MPT_hundredths', 'u1'), ('HeadingStd', 'u1'), ('PitchStd', 'u1'), ('RollStd', 'u1'), ('reserved1', 'S8'), ('ESW1', 'u1'), ('ESW2', 'u1'), ('ESW3', 'u1'), ('ESW4', 'u1')]),
#  'amp': array([[[153, 171, 169, 150],
#          [157, 141, 159, 134],
#          [155, 136, 147, 151],
#          ...,
#          [ 19,  21,  33,  33],
#          [ 20,  19,  27,  40],
#          [ 25,  21,  29,  30]],
#
#         [[176, 158, 148, 139],
#          [137, 170, 140, 158],
#          [139, 149, 167, 137],
#          ...,
#          [ 30,  26,  30,  39],
#          [ 23,  25,  31,  28],
#          [ 27,  25,  30,  45]],
#
#         [[155, 142, 161, 141],
#          [152, 160, 145, 162],
#          [128, 148, 113, 150],
#          ...,
#          [ 32,  27,  33,  34],
#          [ 37,  33,  29,  38],
#          [ 37,  42,  27,  31]],
#
#         ...,
#         [[220, 228, 189, 229],
#          [191, 188, 183, 215],
#          [167, 174, 173, 193],
#          ...,
#          [ 28,  33,  34,  31],
#          [ 31,  39,  32,  40],
#          [ 34,  40,  36,  36]],
#
#         [[211, 224, 189, 227],
#          [188, 186, 177, 224],
#          [168, 173, 169, 198],
#          ...,
#          [ 38,  42,  34,  46],
#          [ 39,  35,  33,  40],
#          [ 52,  57,  39,  53]],
#
#         [[208, 219, 178, 227],
#          [187, 174, 173, 224],
#          [177, 175, 174, 204],
#          ...,
#          [ 32,  27,  32,  38],
#          [ 31,  26,  26,  36],
#          [ 36,  30,  28,  38]]], dtype=uint8),
#  'amp1': array([[153, 157, 155, ...,  19,  20,  25],
#         [176, 137, 139, ...,  30,  23,  27],
#         [155, 152, 128, ...,  32,  37,  37],
#         ...,
#         [220, 191, 167, ...,  28,  31,  34],
#         [211, 188, 168, ...,  38,  39,  52],
#         [208, 187, 177, ...,  32,  31,  36]], dtype=uint8),
#  'amp2': array([[171, 141, 136, ...,  21,  19,  21],
#         [158, 170, 149, ...,  26,  25,  25],
#         [142, 160, 148, ...,  27,  33,  42],
#         ...,
#         [228, 188, 174, ...,  33,  39,  40],
#         [224, 186, 173, ...,  42,  35,  57],
#         [219, 174, 175, ...,  27,  26,  30]], dtype=uint8),
#  'amp3': array([[169, 159, 147, ...,  33,  27,  29],
#         [148, 140, 167, ...,  30,  31,  30],
#         [161, 145, 113, ...,  33,  29,  27],
#         ...,
#         [189, 183, 173, ...,  34,  32,  36],
#         [189, 177, 169, ...,  34,  33,  39],
#         [178, 173, 174, ...,  32,  26,  28]], dtype=uint8),
#  'amp4': array([[150, 134, 151, ...,  33,  40,  30],
#         [139, 158, 137, ...,  39,  28,  45],
#         [141, 162, 150, ...,  34,  38,  31],
#         ...,
#         [229, 215, 193, ...,  31,  40,  36],
#         [227, 224, 198, ...,  46,  40,  53],
#         [227, 224, 204, ...,  38,  36,  38]], dtype=uint8),
#  'bt_depth': masked_array(data =
#   [[-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]],
#               mask =
#   [[ True  True  True  True]
#   [ True  True  True  True]
#   [ True  True  True  True]
#   ...,
#   [ True  True  True  True]
#   [ True  True  True  True]
#   [ True  True  True  True]],
#         fill_value = 1e+20),
#  'bt_vel': masked_array(data =
#   [[-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]],
#               mask =
#   [[ True  True  True  True]
#   [ True  True  True  True]
#   [ True  True  True  True]
#   ...,
#   [ True  True  True  True]
#   [ True  True  True  True]
#   [ True  True  True  True]],
#         fill_value = 1e+20),
#  'bt_xyze': masked_array(data =
#   [[-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]
#   [-- -- -- --]],
#               mask =
#   [[ True  True  True  True]
#   [ True  True  True  True]
#   [ True  True  True  True]
#   ...,
#   [ True  True  True  True]
#   [ True  True  True  True]
#   [ True  True  True  True]],
#         fill_value = 1e+20),
#  'cor': array([[[196, 168, 225, 103],
#          [204, 155, 213, 142],
#          [224, 214, 229, 247],
#          ...,
#          [ 14,  42,  42,  54],
#          [ 25,  29,  17,  49],
#          [ 35,   6,  29,  10]],
#
#         [[216, 226, 237, 191],
#          [223, 237, 226, 243],
#          [229, 218, 218, 229],
#          ...,
#          [ 70,  77,  48,  66],
#          [ 44,   7,  41,  42],
#          [ 15,  23,  14,  27]],
#
#         [[181, 198, 216, 227],
#          [243, 236, 204, 241],
#          [227, 225, 224, 230],
#          ...,
#          [ 15,  35,  28,  19],
#          [ 58,  21,  32,   8],
#          [  8,  39,  31,  48]],
#
#         ...,
#         [[192, 187, 164, 221],
#          [221, 223, 223, 206],
#          [204, 214, 241, 192],
#          ...,
#          [ 86,  60,  79,  26],
#          [ 69,  48,  79,  45],
#          [ 60,  13,  35,  39]],
#
#         [[194, 204, 212, 221],
#          [236, 234, 233, 233],
#          [206, 225, 231, 219],
#          ...,
#          [ 56,  10,  25,  37],
#          [113,  56,  94,  54],
#          [101,  32,  48,  67]],
#
#         [[227, 181, 208, 223],
#          [224, 233, 239, 226],
#          [234, 223, 213, 181],
#          ...,
#          [ 35,  35,  44,  25],
#          [ 58,  84,  39,  23],
#          [155,  52,   6,  29]]], dtype=uint8),
#  'cor1': array([[196, 204, 224, ...,  14,  25,  35],
#         [216, 223, 229, ...,  70,  44,  15],
#         [181, 243, 227, ...,  15,  58,   8],
#         ...,
#         [192, 221, 204, ...,  86,  69,  60],
#         [194, 236, 206, ...,  56, 113, 101],
#         [227, 224, 234, ...,  35,  58, 155]], dtype=uint8),
#  'cor2': array([[168, 155, 214, ...,  42,  29,   6],
#         [226, 237, 218, ...,  77,   7,  23],
#         [198, 236, 225, ...,  35,  21,  39],
#         ...,
#         [187, 223, 214, ...,  60,  48,  13],
#         [204, 234, 225, ...,  10,  56,  32],
#         [181, 233, 223, ...,  35,  84,  52]], dtype=uint8),
#  'cor3': array([[225, 213, 229, ...,  42,  17,  29],
#         [237, 226, 218, ...,  48,  41,  14],
#         [216, 204, 224, ...,  28,  32,  31],
#         ...,
#         [164, 223, 241, ...,  79,  79,  35],
#         [212, 233, 231, ...,  25,  94,  48],
#         [208, 239, 213, ...,  44,  39,   6]], dtype=uint8),
#  'cor4': array([[103, 142, 247, ...,  54,  49,  10],
#         [191, 243, 229, ...,  66,  42,  27],
#         [227, 241, 230, ...,  19,   8,  48],
#         ...,
#         [221, 206, 192, ...,  26,  45,  39],
#         [221, 233, 219, ...,  37,  54,  67],
#         [223, 226, 181, ...,  25,  23,  29]], dtype=uint8),
#  'dday': array([ 207.76093877,  207.76096562,  207.76099248, ...,  207.87886146,
#          207.87888866,  207.87891586]),
#  'dep': array([   8.22,   12.22,   16.22,   20.22,   24.22,   28.22,   32.22,
#           36.22,   40.22,   44.22,   48.22,   52.22,   56.22,   60.22,
#           64.22,   68.22,   72.22,   76.22,   80.22,   84.22,   88.22,
#           92.22,   96.22,  100.22,  104.22,  108.22,  112.22,  116.22,
#          120.22,  124.22,  128.22,  132.22,  136.22,  140.22,  144.22,
#          148.22,  152.22,  156.22,  160.22,  164.22,  168.22,  172.22,
#          176.22,  180.22,  184.22,  188.22,  192.22,  196.22,  200.22,
#          204.22,  208.22,  212.22,  216.22,  220.22,  224.22,  228.22,
#          232.22,  236.22,  240.22,  244.22,  248.22,  252.22,  256.22,
#          260.22,  264.22,  268.22,  272.22,  276.22,  280.22,  284.22,
#          288.22,  292.22,  296.22,  300.22,  304.22,  308.22,  312.22,
#          316.22,  320.22,  324.22]),
#  'ens_num': array([   1,    2,    3, ..., 4345, 4346, 4347]),
#  'heading': array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  'nbins': 80,
#  'nprofs': 4347,
#  'pingtype': 'bb',
#  'pitch': array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  'rVL': rec.array([ (1, 17, 7, 27, 18, 15, 45, 11, 0, 0, 1491, 0, 0, 0, 0, 35, 1044, 0, 0, 52, 0, 0, 0, '', 0, 0, 0, 0),
#   (2, 17, 7, 27, 18, 15, 47, 43, 0, 0, 1491, 0, 0, 0, 0, 35, 1029, 0, 0, 52, 0, 0, 0, '', 0, 0, 0, 0),
#   (3, 17, 7, 27, 18, 15, 49, 75, 0, 0, 1491, 0, 0, 0, 0, 35, 1051, 0, 0, 52, 0, 0, 0, '', 0, 0, 0, 0),
#   ...,
#   (4345, 17, 7, 27, 21, 5, 33, 63, 0, 0, 1496, 0, 0, 0, 0, 35, 1173, 0, 0, 53, 0, 0, 0, '', 3, 0, 0, 0),
#   (4346, 17, 7, 27, 21, 5, 35, 98, 0, 0, 1496, 0, 0, 0, 0, 35, 1188, 0, 0, 53, 0, 0, 0, '', 0, 0, 0, 0),
#   (4347, 17, 7, 27, 21, 5, 38, 33, 0, 0, 1496, 0, 0, 0, 0, 35, 1197, 0, 0, 53, 0, 0, 0, '', 3, 0, 0, 0)],
#            dtype=[('EnsNum', '<u2'), ('Year', 'u1'), ('Month', 'u1'), ('Day', 'u1'), ('Hour', 'u1'), ('Minute', 'u1'), ('Second', 'u1'), ('Hundredths', 'u1'), ('EnsNumMSB', 'u1'), ('BIT', '<u2'), ('SoundSpeed', '<u2'), ('XducerDepth', '<u2'), ('Heading', '<u2'), ('Pitch', '<i2'), ('Roll', '<i2'), ('Salinity', '<u2'), ('Temperature', '<i2'), ('MPT_minutes', 'u1'), ('MPT_seconds', 'u1'), ('MPT_hundredths', 'u1'), ('HeadingStd', 'u1'), ('PitchStd', 'u1'), ('RollStd', 'u1'), ('reserved1', 'S8'), ('ESW1', 'u1'), ('ESW2', 'u1'), ('ESW3', 'u1'), ('ESW4', 'u1')]),
#  'roll': array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  'sysconfig': {'angle': 30, 'convex': True, 'kHz': 150, 'up': False},
#  'temperature': array([ 10.44,  10.29,  10.51, ...,  11.73,  11.88,  11.97]),
#  'times': rec.array([(207.7609767905787, 0.0, 2610.0, 1.0, 207.7609388, 23.16711357460648),
#   (207.761003675625, 2610.0, 2610.0, 2.0, 207.7609656, 23.167140459652778),
#   (207.76103050106482, 5220.0, 2610.0, 3.0, 207.7609925, 23.167167285092592),
#   ...,
#   (207.8788928183218, 4374360.0, 2610.0, 4345.0, 207.8788615, 23.28502960234954),
#   (207.87892001421295, 4376970.0, 2610.0, 4346.0, 207.8788887, 23.28505679824074),
#   (207.87894720975694, 4379580.0, 2610.0, 4347.0, 207.8789159, 23.28508399378472)],
#            dtype=[('u_dday', '<f8'), ('offset', '<f8'), ('n_bytes', '<f8'), ('pingnum', '<f8'), ('instrument_dday', '<f8'), ('m_dday', '<f8')]),
#  'trans': {'binmap': False,
#   'coordsystem': 'beam',
#   'threebeam': False,
#   'tilts': False},
#  'vel': masked_array(data =
#   [[[-0.769 -0.09 2.42 --]
#    [-0.705 -0.394 2.633 -3.513]
#    [-0.556 0.121 2.566 -3.473]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.526 0.598 3.021 -2.852]
#    [-0.36 0.662 3.054 -2.794]
#    [-0.057 0.665 3.011 -2.731]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.621 0.088 2.665 -3.405]
#    [-0.572 0.037 2.685 -3.159]
#    [-0.665 -0.145 2.49 -3.425]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   ...,
#   [[-0.135 -0.116 -0.319 -0.206]
#    [-0.236 0.058 0.068 -0.116]
#    [-0.191 -0.182 -0.054 -0.397]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.112 0.064 0.041 -0.275]
#    [0.0 0.111 0.019 -0.297]
#    [-0.042 0.01 0.159 -0.208]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.499 -0.168 -0.042 -0.399]
#    [-0.271 -0.13 -0.027 -0.551]
#    [-0.139 -0.146 0.142 -0.558]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [0.098 -- -- --]]],
#               mask =
#   [[[False False False  True]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   ...,
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [False  True  True  True]]],
#         fill_value = 1e+20),
#  'vel1': masked_array(data =
#   [[-0.769 -0.705 -0.556 ..., -- -- --]
#   [-0.526 -0.36 -0.057 ..., -- -- --]
#   [-0.621 -0.572 -0.665 ..., -- -- --]
#   ...,
#   [-0.135 -0.236 -0.191 ..., -- -- --]
#   [-0.112 0.0 -0.042 ..., -- -- --]
#   [-0.499 -0.271 -0.139 ..., -- -- 0.098]],
#               mask =
#   [[False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   ...,
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True False]],
#         fill_value = 1e+20),
#  'vel2': masked_array(data =
#   [[-0.09 -0.394 0.121 ..., -- -- --]
#   [0.598 0.662 0.665 ..., -- -- --]
#   [0.088 0.037 -0.145 ..., -- -- --]
#   ...,
#   [-0.116 0.058 -0.182 ..., -- -- --]
#   [0.064 0.111 0.01 ..., -- -- --]
#   [-0.168 -0.13 -0.146 ..., -- -- --]],
#               mask =
#   [[False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   ...,
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]],
#         fill_value = 1e+20),
#  'vel3': masked_array(data =
#   [[2.42 2.633 2.566 ..., -- -- --]
#   [3.021 3.054 3.011 ..., -- -- --]
#   [2.665 2.685 2.49 ..., -- -- --]
#   ...,
#   [-0.319 0.068 -0.054 ..., -- -- --]
#   [0.041 0.019 0.159 ..., -- -- --]
#   [-0.042 -0.027 0.142 ..., -- -- --]],
#               mask =
#   [[False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   ...,
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]],
#         fill_value = 1e+20),
#  'vel4': masked_array(data =
#   [[-- -3.513 -3.473 ..., -- -- --]
#   [-2.852 -2.794 -2.731 ..., -- -- --]
#   [-3.405 -3.159 -3.425 ..., -- -- --]
#   ...,
#   [-0.206 -0.116 -0.397 ..., -- -- --]
#   [-0.275 -0.297 -0.208 ..., -- -- --]
#   [-0.399 -0.551 -0.558 ..., -- -- --]],
#               mask =
#   [[ True False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   ...,
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]
#   [False False False ...,  True  True  True]],
#         fill_value = 1e+20),
#  'xyze': masked_array(data =
#   [[[-- -- -- --]
#    [-0.31099999999999994 -6.146000000000001 -0.5712880913631347
#     -0.1548563850798539]
#    [-0.6770000000000002 -6.0390000000000015 -0.38740203062623874
#     0.33375440072005036]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-1.124 -5.873000000000001 0.06957070743734983 -0.06858935777509523]
#    [-1.0220000000000002 -5.848000000000001 0.16223542564228483
#     0.02969848480983517]
#    [-0.7220000000000002 -5.742000000000001 0.25634351952019396
#     0.23193102422918732]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.7090000000000001 -6.070000000000001 -0.36748344633919666
#     0.1463711037056153]
#    [-0.6090000000000001 -5.844000000000001 -0.2912732108061661
#     -0.043133513652379496]
#    [-0.5200000000000001 -5.915000000000001 -0.5037381098679483
#     0.08838834764831838]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   ...,
#   [[-0.019000000000000003 0.11300000000000002 -0.22401190444557478
#     0.193747258045114]
#    [-0.29400000000000004 -0.18400000000000005 -0.0652405804184277
#     -0.09192388155425116]
#    [-0.009000000000000036 -0.34300000000000014 -0.2378683109061258
#     0.05515432893255079]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.17600000000000005 -0.31600000000000006 -0.08140638795573722
#     0.13152186130069787]
#    [-0.11100000000000003 -0.31600000000000006 -0.04820874747733375
#     0.27506453788156704]
#    [-0.05200000000000001 -0.3670000000000001 -0.023382685902179838
#     0.012020815280171303]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]
#
#   [[-0.33100000000000007 -0.3570000000000001 -0.31985204913105264
#     -0.15980613254815973]
#    [-0.14100000000000004 -0.5240000000000001 -0.2826129567683218
#     0.125157900270019]
#    [0.0069999999999999785 -0.7000000000000002 -0.20236126935096382
#     0.09263098833543776]
#    ...,
#    [-- -- -- --]
#    [-- -- -- --]
#    [-- -- -- --]]],
#               mask =
#   [[[ True  True  True  True]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   ...,
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]
#
#   [[False False False False]
#    [False False False False]
#    [False False False False]
#    ...,
#    [ True  True  True  True]
#    [ True  True  True  True]
#    [ True  True  True  True]]],
#         fill_value = 1e+20),
#  'yearbase': 2017}

# %% [markdown]
# ## Check timestamp when there are multiple files

# %%
data.dday
# Out:
# array([ 207.76093877,  207.76096562,  207.76099248, ...,  207.87886146,
#         207.87888866,  207.87891586])

# %% [markdown]
# ## Verify  data.amp1 is  idential with the first slice of data.amp

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.imshow(data.amp1.T,aspect='auto')
plt.title('data.amp1')

plt.subplot(1,2,2)
plt.imshow(data.amp[:,:,0].T,aspect='auto')
plt.title('data.amp[:,:,0]]')

# %%
plt.figure(figsize=(10,3))
plt.plot(data.amp1[750:850,15],label='data.amp1')
plt.plot(data.amp[750:850,15,0],'r--',label='data.amp[:,:,0]')
plt.legend()

# %%
data.amp1.shape
# Out:
# (22047, 80)

# %%
data.amp.shape
# Out:
# (22047, 80, 4)

# %% [markdown]
# ## Figure out axis labels

# %%
import math

# %%
import datetime

# %%
import jdcal

# %%
data.dday
# Out:
# array([ 209.99999375,  210.00002095,  210.00004815, ...,  210.59807037,
#         210.59809745,  210.59812465])

# %% [markdown]
# ### Test to convert to ping time

# %%
yr1day = jdcal.gcal2jd(data.yearbase,1,1)

# %%
gcal = jdcal.jd2gcal(yr1day[0],yr1day[1]+data.dday[0])
gcal
# Out:
# (2017, 7, 29, 0.9999937500033411)

# %%
tt = datetime.datetime(year=gcal[0],month=gcal[1],day=gcal[2]) +datetime.timedelta(days=gcal[-1])
tt
# Out:
# datetime.datetime(2017, 7, 29, 23, 59, 59, 460000)

# %% [markdown]
# ### Make xtick labels

# %%
ping_jump = 1000
xx_pingtime = data.dday[::ping_jump]  # every 1000th ping
gcal = [jdcal.jd2gcal(yr1day[0],yr1day[1]+x) for x in xx_pingtime]
xx_datetime = [datetime.datetime(year=x[0],month=x[1],day=x[2]) +datetime.timedelta(days=x[-1]) for x in gcal ]
xx_ticklabel = [x.strftime('%H:%M:%S') for x in xx_datetime]
xx_ticklabel
# Out:
# ['23:59:59',
#  '00:39:07',
#  '01:18:10',
#  '01:57:12',
#  '02:36:20',
#  '03:15:30',
#  '03:54:35',
#  '04:33:39',
#  '05:12:41',
#  '05:51:44',
#  '06:30:45',
#  '07:09:45',
#  '07:48:49',
#  '08:27:52',
#  '09:06:56',
#  '09:45:58',
#  '10:25:01',
#  '11:04:05',
#  '11:43:09',
#  '12:22:14',
#  '13:01:20',
#  '13:40:24',
#  '14:19:30']

# %%
data.dep.shape
# Out:
# (80,)

# %% [markdown]
# ### Plot raw amplitude using correct axes

# %%
plt.figure(figsize=(10,3))
plt.imshow(data.amp1.T,aspect='auto')
plt.xticks(range(0,data.amp1.shape[0],ping_jump),xx_ticklabel)
plt.yticks(range(0,data.amp1.shape[1],20),data.dep[::20])
plt.xlabel('Time (hr:min:sec)')
plt.ylabel('Depth (m)')

# %% [markdown]
# ### Check all 4 beams

# %%
fig,ax = plt.subplots(2,2,sharex=True,sharey=True,figsize=(10,6))
#fig = plt.figure(figsize=(10,8))
for i in range(2):
    for j in range(2):
        seq = i*2+j
        ax[i,j].imshow(data.amp[:,:,seq].T,aspect='auto')
        ax[i,j].set_title('Beam '+str(seq))
        ax[i,j].set_xticks(range(0,data.amp1.shape[0],ping_jump))
        ax[i,j].set_xticklabels(xx_ticklabel,fontsize='small')
        ax[i,j].set_yticks(range(0,data.amp1.shape[1],20))
        ax[i,j].set_yticklabels(data.dep[::20],fontsize='small')
#plt.subplots_adjust(wspace=0, hspace=0)

# add a big axes, hide frame
fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')
plt.xlabel("Ping time",fontsize='large')
plt.ylabel("Depth (m)",fontsize='large')

# %% [markdown]
# ### Check transmission loss

# %%
plt.figure(figsize=(10,3))
plt.subplot(121)
plt.imshow(data.amp[:,:,1].T,aspect='auto')
plt.subplot(122)
plt.plot(np.mean(data.amp[:,:,1],axis=0),label='mean: beam 1')
plt.plot(np.mean(data.amp,axis=(0,2)),'r--',label='mean: beam all')
plt.legend()

# %%
plt.figure(figsize=(10,3))
plt.subplot(121)
plt.imshow(data.amp[:,:,1].T,aspect='auto')
plt.title('Raw data.amp')
plt.subplot(122)
plt.imshow((data.amp[:,:,1]-np.mean(data.amp[:,:,1],axis=0)).T,aspect='auto')
plt.title('Raw data.amp - mean across ping')

# %%
m.sysconfig
# Out:
# {'angle': 30, 'convex': True, 'kHz': 150, 'up': False}
